# %% [markdown]
# <a href="https://colab.research.google.com/github/Josesoares18/Trabalho-Pesquisa-Senac/blob/main/C%C3%B3digo%2005/05/2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#UC 2 - Situação de Aprendizagem - Desafio 002
#José Soares

#Criar os códigos devidamente comentados, salvar em um arquivo texto, e salvar na atividade.
#Publicar o código no seu Github

#a)Uma empresa de fornecimento de energia elétrica faz a leitura mensal dos medidores de consumo. Para cada consumidor, são digitados os seguintes dados: 
#• Número do consumidor 
#• Quantidade de KWh consumidos durante o dia. 
#• Tipo (código) do consumidor 
#1. – residencial, preço em reais por KWh = 0,3 
#2. – comercial, preço em reais por KWh = 0,5 
#3.– industrial, preço em reais por KWh = 0,7 
#O algoritmo deverá calcular e mostrar: 
#• O custo total para o consumidor 
#• O total de consumo para os três tipos de consumidor 
#• A média de consumo dos tipos 1 e 2


#a)Uma empresa de fornecimento de energia elétrica faz a leitura mensal dos medidores de consumo. Para cada consumidor, são digitados os seguintes dados: 

print ("a)Uma empresa de fornecimento de energia elétrica faz a leitura mensal dos medidores de consumo. Para cada consumidor, são digitados os seguintes dados: ")
print ("\nInformações: ")
print ("\nTipo 1: Residencial, preço em reais por KWh = 0,3.")
print ("Tipo 2: Comercial, preço em reais por KWh = 0,5.")
print ("Tipo 3: Industrial, preço em reais por KWh = 0,7.")

print ("\nCalculos: ") #Calculos
print ("\nO custo total para o consumidor: ")

print ("\nConsumidor #013") #Consumidor #013
print ("Tipo (código) do consumidor = 1")
print ("Quantidade de KWh consumidos durante o mês = ?")
print ("\nO consumidor #013 utilizou o fornecimento de energia durante 31 dias ou seja:\n")

number_1 = int(7)
number_2 = int(31)
print (number_1 * number_2)

print ("\nConsumidor #027") #Consumidor #027
print ("Tipo (código) do consumidor = 2")
print ("Quantidade de KWh consumidos durante o mês = ?")
print ("\nO consumidor #027 utilizou o fornecimento de energia durante 31 dias ou seja:\n")

number_1 = int(12)
number_2 = int(31)
print (number_1 * number_2)

print ("\nConsumidor #039") #Consumidor #039
print ("Tipo (código) do consumidor = 3")
print ("Quantidade de KWh consumidos durante o mês = ?")
print ("\nO consumidor #039 utilizou o fornecimento de energia durante 31 dias ou seja:\n")

number_1 = int(17)
number_2 = int(31)
print (number_1 * number_2)

print ("\nO total de consumo para os três tipos de consumidor (soma):\n") #O total de consumo para os três tipos de consumidor (soma)

number_1 = int(217)
number_2 = int(372)
number_3 = int(527)
print (number_1 + number_2 + number_3)

print("\nA média de consumo dos tipos 1 e 2:\n")

number_1 = int(589)
number_2 = int(2)
print (number_1 / number_2)


#b)Faça um algoritmo que receba o nome, a idade e o sexo de 2 pessoas e mostre o nome da pessoa apenas se a pessoa for do sexo masculino e tiver mais de 21 anos

print ("\nFaça um algoritmo que receba o nome, a idade e o sexo de 2 pessoas e mostre o nome da pessoa apenas se a pessoa for do sexo masculino e tiver mais de 21 anos:")

print ("\nNome = George")
print ("Idade = 25")
print ("Sexo = Masculino")

print ("\nNome = Maria")
print ("Idade = 20")
print ("Sexo = Feminino")

print ("\nMaior de 21 anos do sexo masculino:\n")

idade = 21
if idade > 21:
    print('Maria')
else:
    print('George')


#Crie um algoritmo que leia um conjunto de pedidos de compra e calcule o valor total da compra. Cada pedido é composto pelos seguintes campos:

print ("\nNumero do pedido: 0193")
print ("Data do pedido: 10/04/2022")
print ("Preço unitário: $20.00")
print ("Quantidade: 05")

print ("\nNumero do pedido: 0284")
print ("Data do pedido: 27/04/2022")
print ("Preço unitário: $45.00")
print ("Quantidade: 03")

print ("\nNumero do pedido: 0375")
print ("Data do pedido: 03/05/2022")
print ("Preço unitário: $80.00")
print ("Quantidade: 02")

print ("\nNumero do pedido: 0471")
print ("Data do pedido: 16/05/2022")
print ("Preço unitário: $120.00")
print ("Quantidade: 03")

print ("\nValor pedido 0193 = $100.00")
print ("Valor pedido 0284 = $135.00")
print ("Valor pedido 0193 = $160.00")
print ("Valor pedido 0193 = $360.00")

print ("\nValor total =\n")

number_1 = int(100)
number_2 = int(135)
number_3 = int(160)
number_4 = int(360)
print (number_1 + number_2 + number_3 + number_4)
# Out:
# a)Uma empresa de fornecimento de energia elétrica faz a leitura mensal dos medidores de consumo. Para cada consumidor, são digitados os seguintes dados:
#
# Informações:
#
# Tipo 1: Residencial, preço em reais por KWh = 0,3.
# Tipo 2: Comercial, preço em reais por KWh = 0,5.
# Tipo 3: Industrial, preço em reais por KWh = 0,7.
#
# Calculos:
#
# O custo total para o consumidor:
#
# Consumidor #013
# Tipo (código) do consumidor = 1
# Quantidade de KWh consumidos durante o mês = ?
#
# O consumidor #013 utilizou o fornecimento de energia durante 31 dias ou seja:
#
# 217
#
# Consumidor #027
# Tipo (código) do consumidor = 2
# Quantidade de KWh consumidos durante o mês = ?
#
# O consumidor #027 utilizou o fornecimento de energia durante 31 dias ou seja:
#
# 372
#
# Consumidor #039
# Tipo (código) do consumidor = 3
# Quantidade de KWh consumidos durante o mês = ?
#
# O consumidor #039 utilizou o fornecimento de energia durante 31 dias ou seja:
#
# 527
#
# ...
